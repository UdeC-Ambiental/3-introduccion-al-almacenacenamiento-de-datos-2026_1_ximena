# %% [markdown]
# 📘 Reto 1 – Lectura y exploración de datos con Pandas
#
# ## 📊 Reto 1: Lectura de datos con pandas
#
# En este ejercicio se aprende a cargar un archivo CSV que contiene datos de calidad del agua, utilizando la biblioteca pandas.

# %%
import pandas as pd

# Leer el archivo CSV
datos = pd.read_csv('../data/4_resultados_agua.csv')

# Mostrar las primeras filas
datos.head()
# Out:
#   Punto   Temp    pH  OD_promedio
# 0     A  22.25  7.15          6.2
# 1     B  24.30  7.20          5.8
# 2     C  19.80  6.85          4.9
# 3     D  23.65  7.05          6.5
# 4     E  25.15  7.25          5.0

# %% [markdown]
# # datos.head()
# 1. Para confirmar que el archivo se cargó bien
# 2. Porque si hay error en la ruta o el archivo, aquí se nota

# %%
datos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Punto        5 non-null      str
#  1   Temp         5 non-null      float64
#  2   pH           5 non-null      float64
#  3   OD_promedio  5 non-null      float64
# dtypes: float64(3), str(1)
# memory usage: 292.0 bytes

# %% [markdown]
# # datos.info()
# 1. Cuántas filas hay, qué columnas existen, tipos de datos Y
# si hay datos faltantes
# 2. Saber si los datos están completos para análisis de calidad del agua

# %%
datos.describe()
# Out:
#             Temp        pH  OD_promedio
# count   5.000000  5.000000     5.000000
# mean   23.030000  7.100000     5.680000
# std     2.093621  0.158114     0.712039
# min    19.800000  6.850000     4.900000
# 25%    22.250000  7.050000     5.000000
# 50%    23.650000  7.150000     5.800000
# 75%    24.300000  7.200000     6.200000
# max    25.150000  7.250000     6.500000

# %% [markdown]
# # datos.describe()
# 1. Obtener: promedios, mínimos y máximos
# 2. Ver el promedio de pH o de oxígeno disuelto

# %%
datos.columns
# Out:
# Index(['Punto', 'Temp', 'pH', 'OD_promedio'], dtype='str')

# %% [markdown]
# # datos.columns
# 1. Saber cómo se llaman exactamente las variables

# %% [markdown]
# # 🧠 Explicación general
#
# Después de cargar los datos, se realiza una exploración inicial del DataFrame. Se utilizan funciones como head(), info() y describe() para conocer la estructura, contenido y características estadísticas de los datos. Esto permite verificar que la información es correcta y adecuada para su análisis.

# %% [markdown]
# # 🌱 Enfoque ambiental
#
# Esta exploración es fundamental en ingeniería ambiental, ya que permite identificar posibles inconsistencias en los datos y comprender el comportamiento de variables como el pH, la temperatura y el oxígeno disuelto en el agua.
